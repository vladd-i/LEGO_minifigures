# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon May  2 15:51:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
GENERATE_RES = 3 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/MyDrive/ANN_LEGO_Project/dataset_preprocessed/minifigures'
EPOCHS = 50
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 96px square images.

# %%
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/MyDrive/ANN_LEGO_Project/dataset_preprocessed/minifigures/training_data_96_96.npy
# Loading previous training pickle...

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join('/content/drive/MyDrive/ANN_LEGO_Project/models','GAN_output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.50053394]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=2.2160110473632812,disc loss=1.0007624626159668, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=2.600982189178467,disc loss=1.0529202222824097, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=2.6111350059509277,disc loss=0.9866964817047119, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=2.6056318283081055,disc loss=1.0048547983169556, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=2.573214530944824,disc loss=1.0000261068344116, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=2.3275279998779297,disc loss=1.0293437242507935, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=2.183981418609619,disc loss=1.0924384593963623, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=2.2475874423980713,disc loss=0.9678391218185425, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=2.20351505279541,disc loss=1.0688639879226685, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=2.2023255825042725,disc loss=1.014890193939209, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=2.232445478439331,disc loss=1.0317959785461426, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=2.22611927986145,disc loss=1.0067102909088135, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=2.141359567642212,disc loss=1.0454262495040894, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=2.1463263034820557,disc loss=1.0559613704681396, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=2.1227645874023438,disc loss=1.0476323366165161, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=2.103074789047241,disc loss=1.0370298624038696, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=2.1662919521331787,disc loss=1.0005792379379272, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=2.19228458404541,disc loss=1.0219472646713257, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=2.188865900039673,disc loss=0.9703384041786194, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=2.267451047897339,disc loss=1.0328755378723145, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=2.242628574371338,disc loss=1.0483759641647339, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=2.194981098175049,disc loss=0.9736700057983398, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=2.1299855709075928,disc loss=1.0207850933074951, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=2.1872527599334717,disc loss=0.9774056673049927, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=2.1485795974731445,disc loss=0.9975102543830872, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=2.2013635635375977,disc loss=0.9923763871192932, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=2.201387882232666,disc loss=0.986717939376831, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=2.225156307220459,disc loss=0.9802600145339966, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=2.203934669494629,disc loss=0.9821316599845886, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=2.2360615730285645,disc loss=0.9772143959999084, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=2.2101995944976807,disc loss=0.9798911809921265, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=2.2048757076263428,disc loss=0.9566075205802917, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=2.19273042678833,disc loss=1.00197172164917, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=2.20298171043396,disc loss=0.9613735675811768, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=2.1883182525634766,disc loss=0.9587131142616272, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=2.2077836990356445,disc loss=0.978539764881134, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=2.2336721420288086,disc loss=0.9108803272247314, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=2.3129024505615234,disc loss=0.9026032090187073, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=2.314455032348633,disc loss=0.9299135804176331, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=2.349874973297119,disc loss=0.9125004410743713, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=2.293515682220459,disc loss=0.9443376064300537, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=2.3224880695343018,disc loss=0.9384596347808838, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=2.324873447418213,disc loss=0.9293513894081116, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=2.3229870796203613,disc loss=0.9191664457321167, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=2.33579421043396,disc loss=0.9318597316741943, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=2.3589394092559814,disc loss=0.8815139532089233, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=2.3546385765075684,disc loss=0.8874871730804443, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=2.398902654647827,disc loss=0.8804462552070618, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=2.360431671142578,disc loss=0.918606698513031, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=2.3715083599090576,disc loss=0.8778508305549622, {hms_string(epoch_elapsed)}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d152560ca122> in <module>()
# ----> 1 train(train_dataset, EPOCHS)
#
# <ipython-input-17-beaaf5d2e204> in train(dataset, epochs)
#      24
#      25   elapsed = time.time()-start
# ---> 26   print (f'Training time: {hms_string(elapsed)}')
#
# NameError: name 'hms_string' is not defined
